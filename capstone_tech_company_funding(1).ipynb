# %% [markdown]
# ### Tech Compnay Fundings

# %%
import pandas as pd
import numpy as np
tech_fund= pd.read_csv("./tech-fundings.csv")

# %%
tech_fund.head(150)
# Out:
#      index      Company                        Website          Region  \
# 0        1     Internxt          https://internxt.com/           Spain
# 1        2     Dockflow           https://dockflow.com         Belgium
# 2        3    api.video              https://api.video          France
# 3        4      Buck.ai               https://buck.ai/   United States
# 4        5    Prodsight       https://www.prodsight.ai  United Kingdom
# ..     ...          ...                            ...             ...
# 145    146  SME Finance     https://www.smefinance.eu/       Lithuania
# 146    147        Finix        https://ridereport.com/   United States
# 147    148      Forager  https://www.finixpayments.com   United States
# 148    149      Moffett    https://www.foragerscs.com/   United States
# 149    150  Ride Report       https://www.zeronorth.io   United States
#
#                     Vertical Funding Amount (USD)   Funding Stage Funding Date
# ...

# %%
irrelevant_data= ['index','Website','Funding Date']

tech_fund.drop(irrelevant_data, axis=1, inplace=True)

tech_fund.head()
# Out:
#      Company          Region                 Vertical Funding Amount (USD)  \
# 0   Internxt           Spain               Blockchain               278940
# 1   Dockflow         Belgium                Logistics               292244
# 2  api.video          France           Developer APIs               300000
# 3    Buck.ai   United States  Artificial Intelligence               300000
# 4  Prodsight  United Kingdom  Artificial Intelligence               529013
#
#   Funding Stage
# 0          Seed
# 1          Seed
# 2          Seed
# 3          Seed
# 4          Seed

# %%
tech_fund.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3575 entries, 0 to 3574
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               3575 non-null   object
#  1   Region                3563 non-null   object
#  2   Vertical              3575 non-null   object
#  3   Funding Amount (USD)  3575 non-null   object
#  4   Funding Stage         3575 non-null   object
# dtypes: object(5)
# memory usage: 139.8+ KB

# %% [markdown]
# ### we are not able to change the funding amount USD from object to int as its numbers

# %%
cond= tech_fund['Region'].isnull()

tech_fund['Region_Clean'] = np.where(cond, 0 , 1) 
tech_fund.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3575 entries, 0 to 3574
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               3575 non-null   object
#  1   Region                3563 non-null   object
#  2   Vertical              3575 non-null   object
#  3   Funding Amount (USD)  3575 non-null   object
#  4   Funding Stage         3575 non-null   object
#  5   Region_Clean          3575 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 167.7+ KB

# %%
tech_funding_type = {
    'Seed': 0,
    'Angle':1,
    'Series A': 2,
    'Series B': 3,
    'Series C': 4,
    'Series D': 5,
    'Series E': 6,
}

# how to know how many series we have in the dataset
# Which method is better, shall we clasify based on the company's funding stage.
tech_fund['Funding Stage'] = tech_fund['Funding Stage'].map( tech_funding_type )
tech_fund.head(50)
# Out:
#             Company          Region                 Vertical  \
# 0          Internxt           Spain               Blockchain
# 1          Dockflow         Belgium                Logistics
# 2         api.video          France           Developer APIs
# 3           Buck.ai   United States  Artificial Intelligence
# 4         Prodsight  United Kingdom  Artificial Intelligence
# 5          Harvestr          France             B2B Software
# 6           Seatrec   United States        Marine Technology
# 7         BeeCanvas   United States             B2B Software
# 8       SmartKarrot   United States             B2B Software
# 9           Prisync          Turkey             B2B Software
# 10     Fundraise Up   United States             B2B Software
# 11              Yac   United States             B2B Software
# 12    Cloverleaf.me   United States          Human Resources
# 13           Docket   United States             B2B Software
# ...
